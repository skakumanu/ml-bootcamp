# %%
import pandas as pd
import datetime
import pandas_datareader.data as web
from pandas import DataFrame, Series

start = datetime.datetime(2020, 1, 1)
end = datetime.datetime(2021, 6, 1)

data = web.DataReader("AAPL", "yahoo", start, end)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-05-19  124.919998  122.860001  123.160004  124.690002  92612000.0
# 2021-05-20  127.720001  125.099998  125.230003  127.309998  76857100.0
# 2021-05-21  128.000000  125.209999  127.820000  125.430000  79209300.0
#
#              Adj Close
# Date
# 2021-05-19  124.690002
# 2021-05-20  127.309998
# 2021-05-21  125.430000

# %%
data.shape
# Out:
# (350, 6)

# %%
data.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
data.tail(3)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-05-19  124.919998  122.860001  123.160004  124.690002  92612000.0
# 2021-05-20  127.720001  125.099998  125.230003  127.309998  76857100.0
# 2021-05-21  128.000000  125.209999  127.820000  125.430000  79209300.0
#
#              Adj Close
# Date
# 2021-05-19  124.690002
# 2021-05-20  127.309998
# 2021-05-21  125.430000

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
data.iloc[:5,:]
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.207466
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.486023
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.071579
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.723213
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.909149

# %%
data.iloc[:-5,:]
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2020-01-02   75.150002   73.797501   74.059998   75.087502  135480400.0
# 2020-01-03   75.144997   74.125000   74.287498   74.357498  146322800.0
# 2020-01-06   74.989998   73.187500   73.447502   74.949997  118387200.0
# 2020-01-07   75.224998   74.370003   74.959999   74.597504  108872000.0
# 2020-01-08   76.110001   74.290001   74.290001   75.797501  132079200.0
# ...                ...         ...         ...         ...          ...
# 2021-05-10  129.539993  126.809998  129.410004  126.849998   88071200.0
# 2021-05-11  126.269997  122.769997  123.500000  125.910004  126142800.0
# 2021-05-12  124.639999  122.250000  123.400002  122.769997  112172300.0
# 2021-05-13  126.150002  124.260002  124.580002  124.970001  105861300.0
# 2021-05-14  127.889999  125.849998  126.250000  127.449997   81806500.0
#
#              Adj Close
# Date
# 2020-01-02   74.207466
# 2020-01-03   73.486023
# 2020-01-06   74.071579
# 2020-01-07   73.723213
# 2020-01-08   74.909149
# ...                ...
# 2021-05-10  126.849998
# 2021-05-11  125.910004
# 2021-05-12  122.769997
# 2021-05-13  124.970001
# 2021-05-14  127.449997
#
# [345 rows x 6 columns]

# %%
data.head(5)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0  74.207466
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.486023
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.071579
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0  73.723213
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.909149

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 350 entries, 2020-01-02 to 2021-05-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       350 non-null    float64
#  1   Low        350 non-null    float64
#  2   Open       350 non-null    float64
#  3   Close      350 non-null    float64
#  4   Volume     350 non-null    float64
#  5   Adj Close  350 non-null    float64
# dtypes: float64(6)
# memory usage: 19.1 KB

# %%
import numpy as np

data.iloc[::3, -1] = np.nan

data.head(6)
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2020-01-02  75.150002  73.797501  74.059998  75.087502  135480400.0        NaN
# 2020-01-03  75.144997  74.125000  74.287498  74.357498  146322800.0  73.486023
# 2020-01-06  74.989998  73.187500  73.447502  74.949997  118387200.0  74.071579
# 2020-01-07  75.224998  74.370003  74.959999  74.597504  108872000.0        NaN
# 2020-01-08  76.110001  74.290001  74.290001  75.797501  132079200.0  74.909149
# 2020-01-09  77.607498  76.550003  76.809998  77.407501  170108400.0  76.500275

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 350 entries, 2020-01-02 to 2021-05-21
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       350 non-null    float64
#  1   Low        350 non-null    float64
#  2   Open       350 non-null    float64
#  3   Close      350 non-null    float64
#  4   Volume     350 non-null    float64
#  5   Adj Close  233 non-null    float64
# dtypes: float64(6)
# memory usage: 19.1 KB

# %%
low = data['Low']

type(low)
# Out:
# pandas.core.series.Series

# %%
low.head()
# Out:
# Date
# 2020-01-02    73.797501
# 2020-01-03    74.125000
# 2020-01-06    73.187500
# 2020-01-07    74.370003
# 2020-01-08    74.290001
# Name: Low, dtype: float64

# %%
lows = low.values
type(lows)
# Out:
# numpy.ndarray
